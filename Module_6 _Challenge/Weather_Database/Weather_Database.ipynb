# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90, high = 89, size = 2000)
lngs = np.random.uniform(low = -180, high = 180, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 715

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ba9da5d5fcdf483202f651fd798eabb6

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bilibino
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | padang
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | ahipara
# Processing Record 9 of Set 1 | clovis
# Processing Record 10 of Set 1 | banda aceh
# Processing Record 11 of Set 1 | lata
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | kalemie
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | martapura
# Processing Record 19 of Set 1 | lompoc
# Processing Record 20 of Set 1 | cayeli
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | sao filipe
# Processing Record 23 of Set 1 | saldanha
# Processing Record 24 of Set 1 | great yarmouth
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | chute-aux-outardes
# Processing Record 27 of Set 1 | caravelas
# Processing Record 28 of Set 1 | zhigansk
# Processing Record 29 of Set 1 | vardo
# Processing Record 30 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | tual
# Processing Record 33 of Set 1 | poum
# Processing Record 34 of Set 1 | jalesar
# Processing Record 35 of Set 1 | kutum
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | guarapari
# Processing Record 38 of Set 1 | tiksi
# Processing Record 39 of Set 1 | faya
# Processing Record 40 of Set 1 | santa fe
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | sangre grande
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | imeni poliny osipenko
# Processing Record 45 of Set 1 | saint-philippe
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | neepawa
# Processing Record 48 of Set 1 | stokmarknes
# Processing Record 49 of Set 1 | mopipi
# Processing Record 50 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 2 | port hawkesbury
# Processing Record 2 of Set 2 | gulariya
# Processing Record 3 of Set 2 | berezovyy
# Processing Record 4 of Set 2 | college
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | fairbanks
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | san luis
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | myitkyina
# Processing Record 11 of Set 2 | upernavik
# Processing Record 12 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | bambous virieux
# Processing Record 16 of Set 2 | shahreza
# Processing Record 17 of Set 2 | upington
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | samarai
# Processing Record 21 of Set 2 | kabo
# Processing Record 22 of Set 2 | siyabuswa
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | norman wells
# Processing Record 25 of Set 2 | codrington
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | rorvik
# Processing Record 28 of Set 2 | hasaki
# Processing Record 29 of Set 2 | ostrovnoy
# Processing Record 30 of Set 2 | dingle
# Processing Record 31 of Set 2 | honiara
# Processing Record 32 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 2 | naruja
# Processing Record 35 of Set 2 | pevek
# Processing Record 36 of Set 2 | diamantino
# Processing Record 37 of Set 2 | tilichiki
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | nouakchott
# Processing Record 41 of Set 2 | rikitea
# Processing Record 42 of Set 2 | zhangye
# Processing Record 43 of Set 2 | balod
# Processing Record 44 of Set 2 | broken hill
# Processing Record 45 of Set 2 | lasa
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | ahuimanu
# Processing Record 48 of Set 2 | dalbandin
# Processing Record 49 of Set 2 | samur
# Processing Record 50 of Set 2 | deshnok
# Processing Record 1 of Set 3 | yellowknife
# Processing Record 2 of Set 3 | savinka
# Processing Record 3 of Set 3 | qui nhon
# Processing Record 4 of Set 3 | hermanus
# Processing Record 5 of Set 3 | kyren
# Processing Record 6 of Set 3 | sao joao da barra
# Processing Record 7 of Set 3 | clyde river
# Processing Record 8 of Set 3 | yerbogachen
# Processing Record 9 of Set 3 | horta
# Processing Record 10 of Set 3 | brae
# Processing Record 11 of Set 3 | comodoro rivadavia
# Processing Record 12 of Set 3 | zalari
# Processing Record 13 of Set 3 | marbella
# Processing Record 14 of Set 3 | vestmannaeyjar
# Processing Record 15 of Set 3 | port hardy
# Processing Record 16 of Set 3 | mahaicony
# City not found. Skipping...
# Processing Record 17 of Set 3 | bahia blanca
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 3 | tuatapere
# Processing Record 21 of Set 3 | sitka
# Processing Record 22 of Set 3 | bethel
# Processing Record 23 of Set 3 | puerto ayora
# Processing Record 24 of Set 3 | nanortalik
# Processing Record 25 of Set 3 | bandarbeyla
# Processing Record 26 of Set 3 | charters towers
# Processing Record 27 of Set 3 | bonthe
# Processing Record 28 of Set 3 | mount isa
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | lavrentiya
# Processing Record 31 of Set 3 | vao
# Processing Record 32 of Set 3 | guerrero negro
# Processing Record 33 of Set 3 | tamandare
# Processing Record 34 of Set 3 | shingu
# Processing Record 35 of Set 3 | hrubieszow
# Processing Record 36 of Set 3 | nelson bay
# Processing Record 37 of Set 3 | kynashiv
# Processing Record 38 of Set 3 | mehamn
# Processing Record 39 of Set 3 | cabo san lucas
# Processing Record 40 of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record 41 of Set 3 | mecca
# Processing Record 42 of Set 3 | atuona
# Processing Record 43 of Set 3 | iqaluit
# Processing Record 44 of Set 3 | port lincoln
# Processing Record 45 of Set 3 | manama
# Processing Record 46 of Set 3 | asyut
# Processing Record 47 of Set 3 | yining
# Processing Record 48 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 3 | atbasar
# Processing Record 50 of Set 3 | pastavy
# Processing Record 1 of Set 4 | yarensk
# Processing Record 2 of Set 4 | san joaquin
# Processing Record 3 of Set 4 | lakes entrance
# Processing Record 4 of Set 4 | chara
# Processing Record 5 of Set 4 | belmonte
# Processing Record 6 of Set 4 | arraial do cabo
# Processing Record 7 of Set 4 | ponta do sol
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | avarua
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | dalhousie
# Processing Record 12 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 4 | vila franca do campo
# Processing Record 15 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 4 | itarema
# Processing Record 17 of Set 4 | carnarvon
# Processing Record 18 of Set 4 | loding
# Processing Record 19 of Set 4 | yar-sale
# Processing Record 20 of Set 4 | cap malheureux
# Processing Record 21 of Set 4 | ucluelet
# Processing Record 22 of Set 4 | qaanaaq
# Processing Record 23 of Set 4 | saint george
# Processing Record 24 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 4 | pangkalanbuun
# Processing Record 26 of Set 4 | olafsvik
# Processing Record 27 of Set 4 | marawi
# Processing Record 28 of Set 4 | hamilton
# Processing Record 29 of Set 4 | vila velha
# Processing Record 30 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 4 | matagami
# Processing Record 33 of Set 4 | enid
# Processing Record 34 of Set 4 | faanui
# Processing Record 35 of Set 4 | maarianhamina
# Processing Record 36 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 37 of Set 4 | kloulklubed
# Processing Record 38 of Set 4 | hokitika
# Processing Record 39 of Set 4 | kruisfontein
# Processing Record 40 of Set 4 | hudson bay
# Processing Record 41 of Set 4 | sinnamary
# Processing Record 42 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 4 | porong
# Processing Record 44 of Set 4 | hope
# Processing Record 45 of Set 4 | fortuna
# Processing Record 46 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 47 of Set 4 | kavieng
# Processing Record 48 of Set 4 | kalabo
# Processing Record 49 of Set 4 | muros
# Processing Record 50 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 5 | taburao
# City not found. Skipping...
# Processing Record 2 of Set 5 | isla mujeres
# Processing Record 3 of Set 5 | torbay
# Processing Record 4 of Set 5 | araouane
# Processing Record 5 of Set 5 | victoria
# Processing Record 6 of Set 5 | san felipe
# Processing Record 7 of Set 5 | katsuura
# Processing Record 8 of Set 5 | benguela
# Processing Record 9 of Set 5 | kaitangata
# Processing Record 10 of Set 5 | seguela
# Processing Record 11 of Set 5 | kodiak
# Processing Record 12 of Set 5 | chicama
# Processing Record 13 of Set 5 | quatre cocos
# Processing Record 14 of Set 5 | haukipudas
# Processing Record 15 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 5 | gigmoto
# Processing Record 17 of Set 5 | puerto carreno
# Processing Record 18 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 5 | pangnirtung
# Processing Record 20 of Set 5 | grand gaube
# Processing Record 21 of Set 5 | chokurdakh
# Processing Record 22 of Set 5 | sitio novo do tocantins
# Processing Record 23 of Set 5 | ustupo
# Processing Record 24 of Set 5 | tommot
# Processing Record 25 of Set 5 | nikolskoye
# Processing Record 26 of Set 5 | hambantota
# Processing Record 27 of Set 5 | mairwa
# Processing Record 28 of Set 5 | kushima
# Processing Record 29 of Set 5 | flin flon
# Processing Record 30 of Set 5 | aklavik
# Processing Record 31 of Set 5 | melfort
# Processing Record 32 of Set 5 | athabasca
# Processing Record 33 of Set 5 | bathsheba
# Processing Record 34 of Set 5 | sengiley
# Processing Record 35 of Set 5 | corovode
# Processing Record 36 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 5 | fritzlar
# Processing Record 38 of Set 5 | bucarasica
# Processing Record 39 of Set 5 | kremenchuk
# Processing Record 40 of Set 5 | burica
# City not found. Skipping...
# Processing Record 41 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 42 of Set 5 | gossaigaon
# Processing Record 43 of Set 5 | ilulissat
# Processing Record 44 of Set 5 | zhezkazgan
# Processing Record 45 of Set 5 | malanje
# Processing Record 46 of Set 5 | beyneu
# Processing Record 47 of Set 5 | cozumel
# Processing Record 48 of Set 5 | kavaratti
# Processing Record 49 of Set 5 | ulaangom
# Processing Record 50 of Set 5 | do gonbadan
# Processing Record 1 of Set 6 | surin
# Processing Record 2 of Set 6 | jiwani
# Processing Record 3 of Set 6 | cidreira
# Processing Record 4 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 6 | trelew
# Processing Record 6 of Set 6 | cairo montenotte
# Processing Record 7 of Set 6 | camabatela
# Processing Record 8 of Set 6 | baghdad
# Processing Record 9 of Set 6 | chkalovsk
# Processing Record 10 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 6 | geraldton
# Processing Record 12 of Set 6 | jacobina
# Processing Record 13 of Set 6 | chenzhou
# Processing Record 14 of Set 6 | port-gentil
# Processing Record 15 of Set 6 | provideniya
# Processing Record 16 of Set 6 | ondjiva
# Processing Record 17 of Set 6 | klaksvik
# Processing Record 18 of Set 6 | high level
# Processing Record 19 of Set 6 | aripuana
# Processing Record 20 of Set 6 | nyurba
# Processing Record 21 of Set 6 | birpur
# Processing Record 22 of Set 6 | coihaique
# Processing Record 23 of Set 6 | auki
# Processing Record 24 of Set 6 | esperance
# Processing Record 25 of Set 6 | ancud
# Processing Record 26 of Set 6 | soyo
# Processing Record 27 of Set 6 | ishinomaki
# Processing Record 28 of Set 6 | buraydah
# Processing Record 29 of Set 6 | otse
# Processing Record 30 of Set 6 | kintampo
# Processing Record 31 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 34 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 6 | ibra
# Processing Record 36 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 6 | troitsko-pechorsk
# Processing Record 38 of Set 6 | berlevag
# Processing Record 39 of Set 6 | gazojak
# Processing Record 40 of Set 6 | raudeberg
# Processing Record 41 of Set 6 | srednekolymsk
# Processing Record 42 of Set 6 | collie
# Processing Record 43 of Set 6 | adrar
# Processing Record 44 of Set 6 | alofi
# Processing Record 45 of Set 6 | brasilia
# Processing Record 46 of Set 6 | bolshiye uki
# City not found. Skipping...
# Processing Record 47 of Set 6 | pavlohrad
# Processing Record 48 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 6 | alamos
# Processing Record 50 of Set 6 | pirovskoye
# Processing Record 1 of Set 7 | snezhnogorsk
# Processing Record 2 of Set 7 | jacksonville
# Processing Record 3 of Set 7 | ouadda
# Processing Record 4 of Set 7 | guangyuan
# Processing Record 5 of Set 7 | ajdabiya
# Processing Record 6 of Set 7 | athens
# Processing Record 7 of Set 7 | jibuti
# Processing Record 8 of Set 7 | yulara
# Processing Record 9 of Set 7 | znamenskoye
# Processing Record 10 of Set 7 | jamkhandi
# Processing Record 11 of Set 7 | ankazoabo
# Processing Record 12 of Set 7 | cayenne
# Processing Record 13 of Set 7 | finote selam
# Processing Record 14 of Set 7 | hofn
# Processing Record 15 of Set 7 | songkhla
# Processing Record 16 of Set 7 | longyearbyen
# Processing Record 17 of Set 7 | hun
# Processing Record 18 of Set 7 | micheweni
# Processing Record 19 of Set 7 | udachnyy
# Processing Record 20 of Set 7 | bakel
# Processing Record 21 of Set 7 | necochea
# Processing Record 22 of Set 7 | taoudenni
# Processing Record 23 of Set 7 | tromso
# Processing Record 24 of Set 7 | halifax
# Processing Record 25 of Set 7 | rawson
# Processing Record 26 of Set 7 | souillac
# Processing Record 27 of Set 7 | xichang
# Processing Record 28 of Set 7 | tepalcatepec
# Processing Record 29 of Set 7 | kaliganj
# Processing Record 30 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 7 | sankeshwar
# Processing Record 32 of Set 7 | mount gambier
# Processing Record 33 of Set 7 | puerto penasco
# Processing Record 34 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 7 | maxixe
# Processing Record 36 of Set 7 | tawnat
# City not found. Skipping...
# Processing Record 37 of Set 7 | monrovia
# Processing Record 38 of Set 7 | iralaya
# Processing Record 39 of Set 7 | teeli
# Processing Record 40 of Set 7 | seoul
# Processing Record 41 of Set 7 | nurota
# Processing Record 42 of Set 7 | eenhana
# Processing Record 43 of Set 7 | yumen
# Processing Record 44 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 7 | tarrafal
# Processing Record 46 of Set 7 | nara
# Processing Record 47 of Set 7 | bengkulu
# Processing Record 48 of Set 7 | san vicente de canete
# Processing Record 49 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 50 of Set 7 | estelle
# Processing Record 1 of Set 8 | san policarpo
# Processing Record 2 of Set 8 | khromtau
# Processing Record 3 of Set 8 | vilnius
# Processing Record 4 of Set 8 | beringovskiy
# Processing Record 5 of Set 8 | nantucket
# Processing Record 6 of Set 8 | labytnangi
# Processing Record 7 of Set 8 | talnakh
# Processing Record 8 of Set 8 | kudahuvadhoo
# Processing Record 9 of Set 8 | krasnoselkup
# Processing Record 10 of Set 8 | linguere
# Processing Record 11 of Set 8 | cherskiy
# Processing Record 12 of Set 8 | zunyi
# Processing Record 13 of Set 8 | porto walter
# Processing Record 14 of Set 8 | saskylakh
# Processing Record 15 of Set 8 | cache creek
# Processing Record 16 of Set 8 | weymouth
# Processing Record 17 of Set 8 | andenes
# Processing Record 18 of Set 8 | avera
# Processing Record 19 of Set 8 | san quintin
# Processing Record 20 of Set 8 | mayo
# Processing Record 21 of Set 8 | barabai
# Processing Record 22 of Set 8 | kigoma
# Processing Record 23 of Set 8 | kirakira
# Processing Record 24 of Set 8 | zarechnyy
# Processing Record 25 of Set 8 | hami
# Processing Record 26 of Set 8 | namibe
# Processing Record 27 of Set 8 | cortez
# Processing Record 28 of Set 8 | waimana
# Processing Record 29 of Set 8 | kananga
# Processing Record 30 of Set 8 | constitucion
# Processing Record 31 of Set 8 | fort nelson
# Processing Record 32 of Set 8 | kapuskasing
# Processing Record 33 of Set 8 | fierze
# City not found. Skipping...
# Processing Record 34 of Set 8 | dois vizinhos
# Processing Record 35 of Set 8 | mantua
# Processing Record 36 of Set 8 | bequimao
# Processing Record 37 of Set 8 | baruun-urt
# Processing Record 38 of Set 8 | tura
# Processing Record 39 of Set 8 | mitsamiouli
# Processing Record 40 of Set 8 | belinskiy
# Processing Record 41 of Set 8 | kuching
# Processing Record 42 of Set 8 | matiri
# Processing Record 43 of Set 8 | zhanakorgan
# Processing Record 44 of Set 8 | kalmunai
# Processing Record 45 of Set 8 | lodja
# Processing Record 46 of Set 8 | mahebourg
# Processing Record 47 of Set 8 | labuhan
# Processing Record 48 of Set 8 | carutapera
# Processing Record 49 of Set 8 | awjilah
# Processing Record 50 of Set 8 | iracoubo
# Processing Record 1 of Set 9 | qiongshan
# Processing Record 2 of Set 9 | aykhal
# Processing Record 3 of Set 9 | khorramshahr
# Processing Record 4 of Set 9 | ballina
# Processing Record 5 of Set 9 | okahandja
# Processing Record 6 of Set 9 | jardim
# Processing Record 7 of Set 9 | mabua
# Processing Record 8 of Set 9 | acajutla
# Processing Record 9 of Set 9 | namatanai
# Processing Record 10 of Set 9 | borogontsy
# Processing Record 11 of Set 9 | funadhoo
# Processing Record 12 of Set 9 | loa janan
# Processing Record 13 of Set 9 | richards bay
# Processing Record 14 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 15 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 9 | katangli
# Processing Record 17 of Set 9 | kuhestan
# City not found. Skipping...
# Processing Record 18 of Set 9 | serrinha
# Processing Record 19 of Set 9 | half moon bay
# Processing Record 20 of Set 9 | san patricio
# Processing Record 21 of Set 9 | pitimbu
# Processing Record 22 of Set 9 | egvekinot
# Processing Record 23 of Set 9 | montes altos
# Processing Record 24 of Set 9 | asau
# Processing Record 25 of Set 9 | sydney
# Processing Record 26 of Set 9 | atar
# Processing Record 27 of Set 9 | fallon
# Processing Record 28 of Set 9 | do rud
# City not found. Skipping...
# Processing Record 29 of Set 9 | verkhnyaya inta
# Processing Record 30 of Set 9 | hudiksvall
# Processing Record 31 of Set 9 | airai
# Processing Record 32 of Set 9 | cabra
# Processing Record 33 of Set 9 | ternate
# Processing Record 34 of Set 9 | naze
# Processing Record 35 of Set 9 | lagoa
# Processing Record 36 of Set 9 | chapais
# Processing Record 37 of Set 9 | marsabit
# Processing Record 38 of Set 9 | kingman
# Processing Record 39 of Set 9 | zeya
# Processing Record 40 of Set 9 | texarkana
# Processing Record 41 of Set 9 | saint-pierre
# Processing Record 42 of Set 9 | jhabua
# Processing Record 43 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 45 of Set 9 | tukrah
# Processing Record 46 of Set 9 | sawakin
# Processing Record 47 of Set 9 | luderitz
# Processing Record 48 of Set 9 | kahului
# Processing Record 49 of Set 9 | zaysan
# Processing Record 50 of Set 9 | san cristobal
# Processing Record 1 of Set 10 | manalurpet
# City not found. Skipping...
# Processing Record 2 of Set 10 | meadow lake
# Processing Record 3 of Set 10 | nome
# Processing Record 4 of Set 10 | los llanos de aridane
# Processing Record 5 of Set 10 | ziro
# Processing Record 6 of Set 10 | la ronge
# Processing Record 7 of Set 10 | grindavik
# Processing Record 8 of Set 10 | selestat
# Processing Record 9 of Set 10 | kutahya
# Processing Record 10 of Set 10 | elliot
# Processing Record 11 of Set 10 | vanimo
# Processing Record 12 of Set 10 | bernau
# Processing Record 13 of Set 10 | progreso
# Processing Record 14 of Set 10 | miri
# Processing Record 15 of Set 10 | mikhaylovka
# Processing Record 16 of Set 10 | bagdarin
# Processing Record 17 of Set 10 | putina
# Processing Record 18 of Set 10 | ilhabela
# Processing Record 19 of Set 10 | sur
# Processing Record 20 of Set 10 | boffa
# Processing Record 21 of Set 10 | grimshaw
# Processing Record 22 of Set 10 | allapalli
# Processing Record 23 of Set 10 | bollnas
# Processing Record 24 of Set 10 | isangel
# Processing Record 25 of Set 10 | gimli
# Processing Record 26 of Set 10 | puerto del rosario
# Processing Record 27 of Set 10 | tautira
# Processing Record 28 of Set 10 | amahai
# Processing Record 29 of Set 10 | brigantine
# Processing Record 30 of Set 10 | sharjah
# Processing Record 31 of Set 10 | lisala
# Processing Record 32 of Set 10 | rosario
# Processing Record 33 of Set 10 | rafaela
# Processing Record 34 of Set 10 | dawei
# Processing Record 35 of Set 10 | fenoarivo
# Processing Record 36 of Set 10 | mol
# Processing Record 37 of Set 10 | salalah
# Processing Record 38 of Set 10 | gaziantep
# Processing Record 39 of Set 10 | mareeba
# Processing Record 40 of Set 10 | ketchikan
# Processing Record 41 of Set 10 | luganville
# Processing Record 42 of Set 10 | cody
# Processing Record 43 of Set 10 | labe
# Processing Record 44 of Set 10 | vostok
# Processing Record 45 of Set 10 | phalaborwa
# Processing Record 46 of Set 10 | taltal
# Processing Record 47 of Set 10 | kargasok
# Processing Record 48 of Set 10 | karak
# Processing Record 49 of Set 10 | portland
# Processing Record 50 of Set 10 | tiarei
# Processing Record 1 of Set 11 | abu dhabi
# Processing Record 2 of Set 11 | kokoda
# Processing Record 3 of Set 11 | esperantinopolis
# Processing Record 4 of Set 11 | vega de alatorre
# Processing Record 5 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 6 of Set 11 | sibolga
# Processing Record 7 of Set 11 | storsteinnes
# Processing Record 8 of Set 11 | tokur
# Processing Record 9 of Set 11 | asfi
# Processing Record 10 of Set 11 | bonavista
# Processing Record 11 of Set 11 | suez
# Processing Record 12 of Set 11 | leningradskiy
# Processing Record 13 of Set 11 | abha
# Processing Record 14 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 11 | mana
# Processing Record 16 of Set 11 | howard springs
# Processing Record 17 of Set 11 | lewistown
# Processing Record 18 of Set 11 | verkhniye kigi
# Processing Record 19 of Set 11 | ixcatepec
# Processing Record 20 of Set 11 | kisangani
# Processing Record 21 of Set 11 | kyabe
# Processing Record 22 of Set 11 | constantine
# Processing Record 23 of Set 11 | cedar city
# Processing Record 24 of Set 11 | miajadas
# Processing Record 25 of Set 11 | verkhnevilyuysk
# Processing Record 26 of Set 11 | duldurga
# Processing Record 27 of Set 11 | breaza
# Processing Record 28 of Set 11 | varnsdorf
# Processing Record 29 of Set 11 | placido de castro
# Processing Record 30 of Set 11 | belyy yar
# Processing Record 31 of Set 11 | denpasar
# Processing Record 32 of Set 11 | thinadhoo
# Processing Record 33 of Set 11 | saint-ambroise
# Processing Record 34 of Set 11 | manasa
# Processing Record 35 of Set 11 | kastornoye
# Processing Record 36 of Set 11 | anori
# Processing Record 37 of Set 11 | khandyga
# Processing Record 38 of Set 11 | san juan
# Processing Record 39 of Set 11 | narsaq
# Processing Record 40 of Set 11 | teguldet
# Processing Record 41 of Set 11 | quelimane
# Processing Record 42 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 11 | laguna
# Processing Record 44 of Set 11 | kralendijk
# Processing Record 45 of Set 11 | ledyard
# Processing Record 46 of Set 11 | chernyshevskiy
# Processing Record 47 of Set 11 | komsomolskiy
# Processing Record 48 of Set 11 | te anau
# Processing Record 49 of Set 11 | harper
# Processing Record 50 of Set 11 | swellendam
# Processing Record 1 of Set 12 | colombia
# Processing Record 2 of Set 12 | codajas
# Processing Record 3 of Set 12 | pogranichnyy
# Processing Record 4 of Set 12 | iturama
# Processing Record 5 of Set 12 | karpathos
# Processing Record 6 of Set 12 | malakal
# Processing Record 7 of Set 12 | port-cartier
# Processing Record 8 of Set 12 | najran
# Processing Record 9 of Set 12 | maturin
# Processing Record 10 of Set 12 | kitchener
# Processing Record 11 of Set 12 | kankan
# Processing Record 12 of Set 12 | urumqi
# Processing Record 13 of Set 12 | guangshui
# Processing Record 14 of Set 12 | haines junction
# Processing Record 15 of Set 12 | gazanjyk
# Processing Record 16 of Set 12 | sirjan
# Processing Record 17 of Set 12 | cockburn town
# Processing Record 18 of Set 12 | mingshui
# Processing Record 19 of Set 12 | kamyshla
# Processing Record 20 of Set 12 | noumea
# Processing Record 21 of Set 12 | ploemeur
# Processing Record 22 of Set 12 | shubarshi
# Processing Record 23 of Set 12 | chum phae
# Processing Record 24 of Set 12 | khoni
# Processing Record 25 of Set 12 | moose factory
# Processing Record 26 of Set 12 | pimampiro
# Processing Record 27 of Set 12 | moron
# Processing Record 28 of Set 12 | sakaiminato
# Processing Record 29 of Set 12 | pacific grove
# Processing Record 30 of Set 12 | boden
# Processing Record 31 of Set 12 | kiama
# Processing Record 32 of Set 12 | san andres
# Processing Record 33 of Set 12 | bubaque
# Processing Record 34 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 35 of Set 12 | paamiut
# Processing Record 36 of Set 12 | meulaboh
# Processing Record 37 of Set 12 | kachiry
# Processing Record 38 of Set 12 | ust-kulom
# Processing Record 39 of Set 12 | amazar
# Processing Record 40 of Set 12 | emerald
# Processing Record 41 of Set 12 | rundu
# Processing Record 42 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 12 | burley
# Processing Record 44 of Set 12 | birigui
# Processing Record 45 of Set 12 | pointe-noire
# Processing Record 46 of Set 12 | ambilobe
# Processing Record 47 of Set 12 | guicheng
# City not found. Skipping...
# Processing Record 48 of Set 12 | karakol
# Processing Record 49 of Set 12 | sakakah
# Processing Record 50 of Set 12 | roebourne
# Processing Record 1 of Set 13 | zaltan
# Processing Record 2 of Set 13 | lorengau
# Processing Record 3 of Set 13 | hobyo
# Processing Record 4 of Set 13 | teberda
# Processing Record 5 of Set 13 | renfrew
# Processing Record 6 of Set 13 | ippy
# Processing Record 7 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 13 | renqiu
# Processing Record 9 of Set 13 | sukhumi
# Processing Record 10 of Set 13 | hirara
# Processing Record 11 of Set 13 | doha
# Processing Record 12 of Set 13 | astoria
# Processing Record 13 of Set 13 | manacapuru
# Processing Record 14 of Set 13 | dymer
# Processing Record 15 of Set 13 | salaverry
# Processing Record 16 of Set 13 | bull savanna
# Processing Record 17 of Set 13 | murray bridge
# Processing Record 18 of Set 13 | rincon
# Processing Record 19 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 13 | drumheller
# Processing Record 21 of Set 13 | astana
# Processing Record 22 of Set 13 | misratah
# Processing Record 23 of Set 13 | saint-joseph
# Processing Record 24 of Set 13 | rio grande
# Processing Record 25 of Set 13 | wagga wagga
# Processing Record 26 of Set 13 | domoni
# Processing Record 27 of Set 13 | mweka
# Processing Record 28 of Set 13 | aberystwyth
# Processing Record 29 of Set 13 | gemena
# Processing Record 30 of Set 13 | hovd
# Processing Record 31 of Set 13 | rocha
# Processing Record 32 of Set 13 | pisco
# Processing Record 33 of Set 13 | oktyabrskoye
# Processing Record 34 of Set 13 | maniitsoq
# Processing Record 35 of Set 13 | prince rupert
# Processing Record 36 of Set 13 | reinosa
# Processing Record 37 of Set 13 | gazli
# Processing Record 38 of Set 13 | muisne
# Processing Record 39 of Set 13 | floro
# Processing Record 40 of Set 13 | vilyuysk
# Processing Record 41 of Set 13 | tadine
# Processing Record 42 of Set 13 | emilio carranza
# Processing Record 43 of Set 13 | gasa
# Processing Record 44 of Set 13 | niteroi
# Processing Record 45 of Set 13 | niquero
# Processing Record 46 of Set 13 | zabaykalsk
# Processing Record 47 of Set 13 | caldwell
# Processing Record 48 of Set 13 | sungaipenuh
# Processing Record 49 of Set 13 | carnot
# Processing Record 50 of Set 13 | sao lourenco do sul
# Processing Record 1 of Set 14 | rio gallegos
# Processing Record 2 of Set 14 | cruzeiro do sul
# Processing Record 3 of Set 14 | veraval
# Processing Record 4 of Set 14 | itapolis
# Processing Record 5 of Set 14 | baykit
# Processing Record 6 of Set 14 | deputatskiy
# Processing Record 7 of Set 14 | chiconautla
# City not found. Skipping...
# Processing Record 8 of Set 14 | buchanan
# Processing Record 9 of Set 14 | trinidad
# Processing Record 10 of Set 14 | eyrarbakki
# Processing Record 11 of Set 14 | lima
# Processing Record 12 of Set 14 | christchurch
# Processing Record 13 of Set 14 | buala
# Processing Record 14 of Set 14 | komsomolskoye
# Processing Record 15 of Set 14 | itaituba
# Processing Record 16 of Set 14 | tuy hoa
# Processing Record 17 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 14 | adamovka
# Processing Record 19 of Set 14 | kharitonovo
# Processing Record 20 of Set 14 | extrema
# Processing Record 21 of Set 14 | nata
# Processing Record 22 of Set 14 | port hedland
# Processing Record 23 of Set 14 | bozuyuk
# Processing Record 24 of Set 14 | petatlan
# Processing Record 25 of Set 14 | newport
# Processing Record 26 of Set 14 | mpika
# Processing Record 27 of Set 14 | neuquen
# Processing Record 28 of Set 14 | margate
# Processing Record 29 of Set 14 | madison heights
# Processing Record 30 of Set 14 | port augusta
# Processing Record 31 of Set 14 | pimenteiras
# Processing Record 32 of Set 14 | great bend
# Processing Record 33 of Set 14 | flinders
# Processing Record 34 of Set 14 | ilo
# Processing Record 35 of Set 14 | zverinogolovskoye
# Processing Record 36 of Set 14 | makung
# City not found. Skipping...
# Processing Record 37 of Set 14 | bryan
# Processing Record 38 of Set 14 | vondrozo
# Processing Record 39 of Set 14 | sept-iles
# Processing Record 40 of Set 14 | antofagasta
# Processing Record 41 of Set 14 | montepuez
# Processing Record 42 of Set 14 | harnoli
# Processing Record 43 of Set 14 | bekasi
# Processing Record 44 of Set 14 | betare oya
# Processing Record 45 of Set 14 | kalga
# Processing Record 46 of Set 14 | svetlogorsk
# Processing Record 47 of Set 14 | sola
# Processing Record 48 of Set 14 | kabanjahe
# Processing Record 49 of Set 14 | mangan
# Processing Record 50 of Set 14 | muroto
# Processing Record 1 of Set 15 | verkh-usugli
# Processing Record 2 of Set 15 | kamenka
# Processing Record 3 of Set 15 | skjervoy
# Processing Record 4 of Set 15 | metro
# Processing Record 5 of Set 15 | ginir
# Processing Record 6 of Set 15 | roald
# Processing Record 7 of Set 15 | black river
# Processing Record 8 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 9 of Set 15 | porto velho
# Processing Record 10 of Set 15 | davila
# Processing Record 11 of Set 15 | palmer
# Processing Record 12 of Set 15 | podborany
# Processing Record 13 of Set 15 | boone
# Processing Record 14 of Set 15 | lufilufi
# Processing Record 15 of Set 15 | guiratinga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 656

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bilibino  68.0546  166.4372     25.16        68          74
# 1     Port Alfred -33.5906   26.8910     60.53        85           0
# 2        Khatanga  71.9667  102.5000     29.23        97          99
# 3  Port Elizabeth -33.9180   25.5701     58.32        90           5
# 4          Padang  -0.9492  100.3543     80.65        84         100
# 5      Bredasdorp -34.5322   20.0403     46.80        86          64
# 6       Busselton -33.6500  115.3333     57.49        61          75
# 7         Ahipara -35.1667  173.1667     57.56        82         100
# 8          Clovis  36.8252 -119.7029     79.84        46           0
# 9      Banda Aceh   5.5577   95.3222     79.70        82         100
#
#    Wind Speed Country Current Description
# 0        5.28      RU       broken clouds
# 1        8.70      ZA           clear sky
# 2        5.86      RU          light snow
# 3        4.00      ZA           clear sky
# 4        7.07      ID     overcast clouds
# 5        5.14      ZA       broken clouds
# 6       18.81      AU       broken clouds
# 7       15.52      NZ     overcast clouds
# 8        5.75      US           clear sky
# 9        7.83      ID     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_list = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df.reindex(columns = column_list)

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bilibino      RU  68.0546  166.4372     25.16        68          74
# 1     Port Alfred      ZA -33.5906   26.8910     60.53        85           0
# 2        Khatanga      RU  71.9667  102.5000     29.23        97          99
# 3  Port Elizabeth      ZA -33.9180   25.5701     58.32        90           5
# 4          Padang      ID  -0.9492  100.3543     80.65        84         100
# 5      Bredasdorp      ZA -34.5322   20.0403     46.80        86          64
# 6       Busselton      AU -33.6500  115.3333     57.49        61          75
# 7         Ahipara      NZ -35.1667  173.1667     57.56        82         100
# 8          Clovis      US  36.8252 -119.7029     79.84        46           0
# 9      Banda Aceh      ID   5.5577   95.3222     79.70        82         100
#
#    Wind Speed Current Description
# 0        5.28       broken clouds
# 1        8.70           clear sky
# 2        5.86          light snow
# 3        4.00           clear sky
# 4        7.07     overcast clouds
# 5        5.14       broken clouds
# 6       18.81       broken clouds
# 7       15.52     overcast clouds
# 8        5.75           clear sky
# 9        7.83     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
